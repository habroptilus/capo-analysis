# %% [markdown]
# # original.txtの中身を調べる

# %% [markdown]
# * すでに表記ゆれはある程度前処理されている
# * original.txtからデータセットを作成する方法はいくつかある
# * capoの方は、半音下げ(-1) ~ capo5(-5)までが大半を占めているので、6と7は削除でよさそう
# * chordの方はいろいろある。低頻度のコードを削除する、何らかのコードで置き換えるなど
# * とりあえず削除する方向で

# %%
from pathlib import Path

# %%
orignal_path=Path("../data/original.txt")

# %%
def get_song_list(original_path):
    with orignal_path.open("r") as f:
        songs = f.readlines()
    result=[]
    for song in songs:
        song=song.rstrip('\n')
        divided=song.split(" ")
        song_dic={"chords":divided[:-1],"rec_capo":divided[-1]}
        result.append(song_dic)
    return result

def remove_rare_capo_song(songs):
    """-6,-7はほとんどないので除去する."""
    removed=[]
    for song in songs:
        if song["rec_capo"] not in ['-6','-7']:
            removed.append(song)
    return removed

# %%
from collections import Counter

def retrieve_chord_stat(songs):
    chord_dict = Counter()
    for song in songs:
        for chord in song["chords"]: 
            chord_dict[chord]+=1
    return chord_dict

def retrieve_capo_stat(songs):
    capo_dict =  Counter()
    for song in songs:
        capo_dict[song["rec_capo"]]+=1
    return capo_dict

# %%
songs=get_song_list(orignal_path)
songs=remove_rare_capo_song(songs)

# %%
chord_stat=retrieve_chord_stat(songs)
capo_stat=retrieve_capo_stat(songs)

# %% [markdown]
# ## chordの出現頻度調査
# * 低頻度chordはparseミスとかも含むので除去したい
# * 5回以下しか出現しない約140個のコードを対象？

# %%
import numpy as np
import matplotlib.pyplot as plt

print(f"Total chords :{len(chord_stat.keys())}")

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
edges = range(0,100,5)
ax.hist(list(chord_stat.values()), bins=edges)
ax.set_title('histogram of chord')
ax.set_xlabel('frequency')
ax.set_ylabel('the number of chords')
fig.show()
# Out:
# Total chords :859
# /Users/hikaru/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
def tokenize_rare_chord(chords_list,chord_stat,threshold=5,token="<UNK>"):
    result=[]
    for chords in chords_list:
        result_inner=[]
        for i,chord in enumerate(chords):
            if (chord not in chord_stat.keys()) or (chord_stat[chord]<=threshold):
                result_inner.append(token)
            else:
                result_inner.append(chord)
        result.append(result_inner)
    return result

def get_onehot_dict(chord_stat,threshold=5,token="<UNK>"):
    onehot_dict={}
    i=0
    for chord,freq in chord_stat.items():
        if freq>threshold:
            onehot_dict[chord]=i
            i+=1
    onehot_dict[token]=i
    return onehot_dict  

def count_and_normalize_chord_features(tokenized,onehot_dict):
    X=[]
    features_num=len(onehot_dict)
    for chords in tokenized:
        x=[0]*features_num
        for chord in chords:
            x[onehot_dict[chord]]+=1
        x=np.array(x)
        X.append(x/sum(x))
    return np.array(X)

def get_chord_features(songs,threshold=5,token="<UNK>"):
    chords_list=[song["chords"] for song in songs]
    chord_stat=retrieve_chord_stat(songs)
    tokenized=tokenize_rare_chord(chords_list,chord_stat)
    onehot_dict=get_onehot_dict(chord_stat)
    X=count_and_normalize_chord_features(tokenized,onehot_dict)
    return X, onehot_dict

# %%
X,onehot_dict=get_chord_features(songs)

# %%
X.shape,onehot_dict
# Out:
# ((39995, 704),
#  {'<UNK>': 703,
#   'A': 13,
#   'A#': 39,
#   'A#-5': 334,
#   'A#/A': 93,
#   'A#/B': 625,
#   'A#/C': 207,
#   'A#/C#': 463,
#   'A#/D': 368,
#   'A#/D#': 382,
#   'A#/E': 573,
#   'A#/F': 316,
#   'A#/F#': 383,
#   'A#/G': 114,
#   'A#/G#': 198,
#   'A#6': 285,
#   'A#7': 76,
#   'A#7+5': 462,
#   'A#7-5': 339,
#   'A#7-9': 395,
#   'A#7/D#': 311,
#   'A#7/G#': 656,
#   'A#7sus4': 270,
#   'A#9': 360,
#   'A#M9': 648,
#   'A#add9': 91,
#   'A#aug': 141,
#   'A#aug/E': 626,
#   'A#dim': 154,
#   'A#m': 24,
#   'A#m/A': 655,
#   'A#m/C': 237,
#   'A#m/C#': 422,
#   'A#m/D': 632,
#   'A#m/D#': 487,
#   'A#m/F#': 429,
#   'A#m/G': 538,
#   'A#m/G#': 295,
#   'A#m6': 329,
#   'A#m6/C': 528,
#   'A#m7': 88,
#   'A#m7-5': 192,
#   'A#m7-5/D#': 362,
#   'A#m7/D#': 275,
#   'A#m7/F#': 594,
#   'A#m7/G#': 590,
#   'A#m9': 361,
#   'A#mM7': 280,
#   'A#madd9': 490,
#   'A#maj7': 44,
#   'A#maj7/C': 476,
#   'A#maj9': 467,
#   'A#sus4': 200,
#   'A#sus4/C': 657,
#   'A#sus4/D': 597,
#   'A#sus4/G': 549,
#   'A#sus4/G#': 628,
#   'A-5': 685,
#   'A/A#': 599,
#   'A/B': 193,
#   'A/C': 605,
#   'A/C#': 331,
#   'A/D': 112,
#   'A/D#': 268,
#   'A/E': 481,
#   'A/F': 515,
#   'A/F#': 455,
#   'A/G': 111,
#   'A/G#': 282,
#   'A6': 31,
#   'A7': 40,
#   'A7(9)': 353,
#   'A7+5': 642,
#   'A7-5': 400,
#   'A7-9': 556,
#   'A7/C#': 420,
#   'A7/D': 492,
#   'A7/F': 670,
#   'A7/G': 584,
#   'A7/G#': 663,
#   'A7sus4': 132,
#   'A9': 442,
#   'Aadd9': 16,
#   'Aadd9/D': 291,
#   'Aadd9/F#': 522,
#   'Aaug': 157,
#   'Adim': 307,
#   'Am': 57,
#   'Am/B': 443,
#   'Am/C': 533,
#   'Am/D': 212,
#   'Am/F': 525,
#   'Am/F#': 568,
#   'Am/G': 128,
#   'Am/G#': 548,
#   'Am6': 266,
#   'Am6/B': 195,
#   'Am7': 68,
#   'Am7-5': 224,
#   'Am7-5/D': 227,
#   'Am7/A#': 686,
#   'Am7/D': 213,
#   'Am7/F': 252,
#   'Am7/G': 647,
#   'Am7/G#': 435,
#   'Am9': 217,
#   'AmM7': 202,
#   'Amadd9': 356,
#   'Amaj7': 15,
#   'Amaj7/B': 408,
#   'Amaj7/D': 671,
#   'Amaj9': 504,
#   'Asus4': 72,
#   'Asus4/B': 290,
#   'Asus4/C#': 264,
#   'Asus4/F#': 432,
#   'Asus4/G': 531,
#   'B': 0,
#   'B-5': 536,
#   'B/A': 116,
#   'B/A#': 113,
#   'B/C': 496,
#   'B/C#': 178,
#   'B/D': 299,
#   'B/D#': 300,
#   'B/E': 121,
#   'B/F': 581,
#   'B/F#': 366,
#   'B/G': 637,
#   'B/G#': 117,
#   'B6': 32,
#   'B7': 30,
#   'B7+5': 616,
#   'B7-5': 417,
#   'B7-9': 256,
#   'B7/D#': 695,
#   'B7/E': 137,
#   'B7sus4': 169,
#   'B9': 255,
#   'Badd9': 34,
#   'Badd9/E': 662,
#   'Badd9/G#': 687,
#   'Baug': 305,
#   'Baug/F': 609,
#   'Bdim': 49,
#   'Bm': 55,
#   'Bm-5': 163,
#   'Bm/A': 142,
#   'Bm/A#': 413,
#   'Bm/C#': 309,
#   'Bm/D': 654,
#   'Bm/D#': 652,
#   'Bm/E': 346,
#   'Bm/G': 569,
#   'Bm/G#': 347,
#   'Bm6': 327,
#   'Bm6/C#': 153,
#   'Bm7': 70,
#   'Bm7-5': 43,
#   'Bm7-5/E': 529,
#   'Bm7/A': 260,
#   'Bm7/A#': 243,
#   'Bm7/C': 689,
#   'Bm7/E': 191,
#   'Bm7/G': 433,
#   'Bm9': 209,
#   'BmM7': 261,
#   'Bmadd9': 384,
#   'Bmaj7': 7,
#   'Bmaj7/C#': 540,
#   'Bmaj7/E': 645,
#   'Bmaj9': 488,
#   'Bsus4': 29,
#   'Bsus4/A': 514,
#   'Bsus4/C#': 354,
#   'Bsus4/D#': 579,
#   'Bsus4/G#': 593,
#   'C': 26,
#   'C#': 21,
#   'C#-5': 544,
#   'C#/A': 454,
#   'C#/A#': 62,
#   'C#/B': 61,
#   'C#/C': 129,
#   'C#/D': 635,
#   'C#/D#': 89,
#   'C#/E': 508,
#   'C#/F': 333,
#   'C#/F#': 273,
#   'C#/G': 495,
#   'C#/G#': 396,
#   'C#6': 147,
#   'C#7': 95,
#   'C#7+5': 507,
#   'C#7-5': 304,
#   'C#7-9': 180,
#   'C#7/F': 374,
#   'C#7/F#': 512,
#   'C#7sus4': 168,
#   'C#9': 446,
#   'C#add9': 108,
#   'C#add9/A#': 302,
#   'C#aug': 160,
#   'C#aug/G': 543,
#   'C#dim': 211,
#   'C#m': 12,
#   'C#m/A': 554,
#   'C#m/A#': 289,
#   'C#m/B': 120,
#   'C#m/C': 283,
#   'C#m/D#': 503,
#   'C#m/F': 457,
#   'C#m/F#': 288,
#   'C#m6': 74,
#   'C#m6/D#': 539,
#   'C#m7': 6,
#   'C#m7-5': 75,
#   'C#m7-5/F#': 588,
#   'C#m7/A': 565,
#   'C#m7/B': 691,
#   'C#m7/D': 69,
#   'C#m7/F#': 201,
#   'C#m9': 518,
#   'C#mM7': 265,
#   'C#madd9': 248,
#   'C#maj7': 102,
#   'C#maj7/D#': 449,
#   'C#maj9': 444,
#   'C#sus4': 58,
#   'C#sus4/A#': 465,
#   'C#sus4/B': 315,
#   'C#sus4/D#': 619,
#   'C-5': 328,
#   'C/A': 238,
#   'C/A#': 182,
#   'C/B': 127,
#   'C/C#': 164,
#   'C/D': 126,
#   'C/D#': 375,
#   'C/E': 604,
#   'C/F': 317,
#   'C/F#': 583,
#   'C/G': 532,
#   'C/G#': 477,
#   'C6': 159,
#   'C7': 80,
#   'C7+5': 281,
#   'C7-5': 378,
#   'C7-9': 349,
#   'C7/A#': 567,
#   'C7/E': 697,
#   'C7/F': 684,
#   'C7sus4': 249,
#   'C9': 335,
#   'CM': 701,
#   'CM7': 674,
#   'Cadd9': 50,
#   'Cadd9/A': 506,
#   'Caug': 171,
#   'Caug/F#': 582,
#   'Cdim': 130,
#   'Cm': 20,
#   'Cm-5': 152,
#   'Cm/A': 401,
#   'Cm/A#': 336,
#   'Cm/B': 534,
#   'Cm/D': 479,
#   'Cm/D#': 591,
#   'Cm/E': 640,
#   'Cm/F': 405,
#   'Cm/G#': 431,
#   'Cm6': 262,
#   'Cm6/D': 600,
#   'Cm7': 48,
#   'Cm7-5': 150,
#   'Cm7/A#': 424,
#   'Cm7/F': 138,
#   'Cm7/G#': 682,
#   'Cm9': 386,
#   'CmM7': 271,
#   'Cmadd9': 464,
#   'Cmaj7': 73,
#   'Cmaj7/D': 576,
#   'Cmaj7/F': 679,
#   'Cmaj9': 452,
#   'Csus4': 85,
#   'Csus4/A': 497,
#   'Csus4/A#': 318,
#   'Csus4/D': 478,
#   'Csus4/E': 437,
#   'D': 41,
#   'D#': 22,
#   'D#-5': 535,
#   'D#/A': 493,
#   'D#/A#': 369,
#   'D#/B': 559,
#   'D#/C': 131,
#   'D#/C#': 25,
#   'D#/D': 301,
#   'D#/E': 552,
#   'D#/F': 204,
#   'D#/F#': 634,
#   'D#/G': 403,
#   'D#/G#': 306,
#   'D#6': 86,
#   'D#7': 77,
#   'D#7+5': 430,
#   'D#7-5': 240,
#   'D#7-9': 320,
#   'D#7/A': 388,
#   'D#7/G': 572,
#   'D#7/G#': 489,
#   'D#7sus4': 105,
#   'D#9': 391,
#   'D#add9': 67,
#   'D#add9/C': 606,
#   'D#add9/D': 453,
#   'D#add9/G#': 607,
#   'D#aug': 352,
#   'D#aug/A': 560,
#   'D#dim': 247,
#   'D#m': 5,
#   'D#m/B': 516,
#   'D#m/C': 557,
#   'D#m/C#': 371,
#   'D#m/D': 439,
#   'D#m/F': 187,
#   'D#m/G#': 359,
#   'D#m6': 312,
#   'D#m7': 28,
#   'D#m7-5': 232,
#   'D#m7-5/G#': 458,
#   'D#m7/A': 665,
#   'D#m7/B': 505,
#   'D#m7/C#': 367,
#   'D#m7/D': 558,
#   'D#m7/G#': 231,
#   'D#m9': 578,
#   'D#mM7': 230,
#   'D#madd9': 438,
#   'D#maj7': 143,
#   'D#maj7/F': 498,
#   'D#maj7/G#': 601,
#   'D#maj9': 482,
#   'D#sus4': 84,
#   'D#sus4/C': 550,
#   'D#sus4/C#': 617,
#   'D#sus4/F': 500,
#   'D#sus4/G': 527,
#   'D-5': 274,
#   'D/A': 332,
#   'D/A#': 404,
#   'D/B': 254,
#   'D/C': 66,
#   'D/C#': 166,
#   'D/D#': 551,
#   'D/E': 82,
#   'D/F': 146,
#   'D/F#': 214,
#   'D/G': 71,
#   'D/G#': 509,
#   'D6': 222,
#   'D7': 65,
#   'D7+5': 226,
#   'D7-5': 355,
#   'D7-9': 322,
#   'D7/C': 678,
#   'D7/F#': 659,
#   'D7/G': 292,
#   'D7/G#': 541,
#   'D7sus4': 250,
#   'D9': 392,
#   'DM9': 621,
#   'Dadd9': 90,
#   'Dadd9/B': 298,
#   'Dadd9/G': 426,
#   'Daug': 156,
#   'Daug/G#': 373,
#   'Ddim': 177,
#   'Dm': 36,
#   'Dm-5': 151,
#   'Dm/A#': 338,
#   'Dm/B': 365,
#   'Dm/C': 276,
#   'Dm/C#': 364,
#   'Dm/E': 251,
#   'Dm/F': 592,
#   'Dm/G': 491,
#   'Dm6': 155,
#   'Dm6/E': 702,
#   'Dm7': 42,
#   'Dm7-5': 236,
#   'Dm7-5/G': 253,
#   'Dm7/A#': 563,
#   'Dm7/C': 380,
#   'Dm7/D#': 624,
#   'Dm7/G': 99,
#   'Dm7/G#': 602,
#   'Dm9': 218,
#   'DmM7': 229,
#   'Dmadd9': 357,
#   'Dmaj7': 17,
#   'Dmaj7/E': 190,
#   'Dmaj7/G': 667,
#   'Dmaj9': 344,
#   'Dsus4': 56,
#   'Dsus4/B': 618,
#   'Dsus4/C': 460,
#   'Dsus4/E': 473,
#   'Dsus4/F#': 434,
#   'E': 3,
#   'E-5': 561,
#   'E/A': 124,
#   'E/A#': 406,
#   'E/B': 337,
#   'E/C': 215,
#   'E/C#': 97,
#   'E/D': 118,
#   'E/D#': 96,
#   'E/F': 440,
#   'E/F#': 244,
#   'E/G': 423,
#   'E/G#': 219,
#   'E6': 139,
#   'E7': 100,
#   'E7+5': 629,
#   'E7+9': 340,
#   'E7-5': 461,
#   'E7-9': 379,
#   'E7/A': 414,
#   'E7/A#': 547,
#   'E7/D': 683,
#   'E7/G#': 421,
#   'E7sus4': 186,
#   'E9': 321,
#   'Eadd9': 4,
#   'Eadd9/A': 475,
#   'Eadd9/C#': 553,
#   'Eadd9/D#': 427,
#   'Eaug': 140,
#   'Eaug/A#': 575,
#   'Edim': 242,
#   'Em': 52,
#   'Em/A': 296,
#   'Em/C': 537,
#   'Em/C#': 389,
#   'Em/D': 133,
#   'Em/D#': 411,
#   'Em/F#': 325,
#   'Em/G#': 480,
#   'Em6': 54,
#   'Em6/F#': 699,
#   'Em7': 53,
#   'Em7-5': 205,
#   'Em7-5/A': 188,
#   'Em7/A': 196,
#   'Em7/A#': 675,
#   'Em7/C': 650,
#   'Em7/D': 646,
#   'Em7/D#': 669,
#   'Em9': 170,
#   'EmM7': 161,
#   'Emadd9': 415,
#   'Emaj7': 8,
#   'Emaj7/A': 519,
#   'Emaj7/F#': 520,
#   'Emaj9': 450,
#   'Esus4': 35,
#   'Esus4/C#': 623,
#   'Esus4/D': 441,
#   'Esus4/F#': 412,
#   'Esus4/G#': 596,
#   'F': 38,
#   'F#': 1,
#   'F#-5': 562,
#   'F#/A': 517,
#   'F#/A#': 419,
#   'F#/B': 277,
#   'F#/C': 397,
#   'F#/C#': 324,
#   'F#/D': 608,
#   'F#/D#': 185,
#   'F#/E': 106,
#   'F#/F': 184,
#   'F#/G': 598,
#   'F#/G#': 92,
#   'F#6': 9,
#   'F#7': 94,
#   'F#7+5': 676,
#   'F#7-5': 577,
#   'F#7-9': 326,
#   'F#7/A#': 513,
#   'F#7/B': 474,
#   'F#7sus4': 104,
#   'F#9': 351,
#   'F#add9': 241,
#   'F#add9/B': 370,
#   'F#add9/D#': 342,
#   'F#add9/F': 341,
#   'F#aug': 123,
#   'F#aug/C': 580,
#   'F#dim': 267,
#   'F#m': 45,
#   'F#m/A': 631,
#   'F#m/B': 377,
#   'F#m/D': 486,
#   'F#m/D#': 259,
#   'F#m/E': 258,
#   'F#m/F': 257,
#   'F#m/G#': 459,
#   'F#m6': 174,
#   'F#m7': 10,
#   'F#m7-5': 145,
#   'F#m7-5/B': 194,
#   'F#m7/B': 167,
#   'F#m7/D': 668,
#   'F#m7/E': 223,
#   'F#m9': 33,
#   'F#mM7': 221,
#   'F#madd9': 501,
#   'F#maj7': 148,
#   'F#maj7/G#': 545,
#   'F#maj9': 381,
#   'F#sus4': 27,
#   'F#sus4/A#': 239,
#   'F#sus4/D#': 638,
#   'F#sus4/E': 555,
#   'F#sus4/G#': 636,
#   'F-5': 510,
#   'F/A': 216,
#   'F/A#': 286,
#   'F/B': 523,
#   'F/C': 372,
#   'F/C#': 639,
#   'F/D': 125,
#   'F/D#': 79,
#   'F/E': 278,
#   'F/F#': 643,
#   'F/G': 103,
#   'F/G#': 494,
#   'F6': 293,
#   'F7': 47,
#   'F7+5': 319,
#   'F7-5': 162,
#   'F7-9': 448,
#   'F7/A': 589,
#   'F7/A#': 313,
#   'F7/D#': 693,
#   'F7sus4': 183,
#   'F9': 376,
#   'FM7': 119,
#   'Fadd9': 98,
#   'Fadd9/A#': 470,
#   'Fadd9/D': 471,
#   'Fadd9/E': 653,
#   'Faug': 308,
#   'Fdim': 225,
#   'Fm': 23,
#   'Fm/A': 499,
#   'Fm/A#': 393,
#   'Fm/C#': 530,
#   'Fm/D': 587,
#   'Fm/D#': 83,
#   'Fm/E': 586,
#   'Fm/G': 189,
#   'Fm/G#': 694,
#   'Fm6': 173,
#   'Fm6/G': 614,
#   'Fm7': 87,
#   'Fm7-5': 176,
#   'Fm7-5/A#': 399,
#   'Fm7/A#': 197,
#   'Fm7/C#': 546,
#   'Fm7/D#': 698,
#   'Fm7/E': 358,
#   'Fm7/F#': 681,
#   'Fm9': 363,
#   'FmM7': 172,
#   'Fmadd9': 456,
#   'Fmaj7': 14,
#   'Fmaj7/G': 206,
#   'Fmaj9': 466,
#   'Fsus4': 122,
#   'Fsus4/D': 688,
#   'Fsus4/D#': 644,
#   'Fsus4/G': 641,
#   'G': 51,
#   'G#': 19,
#   'G#-5': 542,
#   'G#/A': 615,
#   'G#/A#': 234,
#   'G#/B': 603,
#   'G#/C': 387,
#   'G#/C#': 348,
#   'G#/D': 521,
#   'G#/D#': 269,
#   'G#/E': 484,
#   'G#/F': 345,
#   'G#/F#': 136,
#   'G#/G': 115,
#   'G#6': 272,
#   'G#7': 60,
#   'G#7+5': 649,
#   'G#7-5': 407,
#   'G#7-9': 410,
#   'G#7/C': 677,
#   'G#7/C#': 511,
#   'G#7/D': 666,
#   'G#7sus4': 59,
#   'G#9': 472,
#   'G#M7': 690,
#   'G#add9': 343,
#   'G#add9/F': 385,
#   'G#aug': 228,
#   'G#aug/D': 633,
#   'G#dim': 246,
#   'G#m': 2,
#   'G#m/A#': 595,
#   'G#m/B': 398,
#   'G#m/C#': 483,
#   'G#m/E': 661,
#   'G#m/F': 664,
#   'G#m/F#': 208,
#   'G#m/G': 284,
#   'G#m6': 323,
#   'G#m6/A#': 673,
#   'G#m7': 11,
#   'G#m7-5': 149,
#   'G#m7-5/C#': 630,
#   'G#m7/A': 571,
#   'G#m7/C#': 179,
#   'G#m7/D': 692,
#   'G#m7/E': 570,
#   'G#m7/F#': 658,
#   'G#m9': 310,
#   'G#mM7': 287,
#   'G#madd9': 485,
#   'G#maj7': 81,
#   'G#maj7/A#': 436,
#   'G#maj9': 445,
#   'G#sus4': 18,
#   'G#sus4/A#': 611,
#   'G#sus4/C': 672,
#   'G#sus4/F': 612,
#   'G#sus4/F#': 610,
#   'G-5': 64,
#   'G/A': 158,
#   'G/A#': 199,
#   'G/B': 220,
#   'G/C': 303,
#   'G/C#': 524,
#   'G/D': 409,
#   'G/D#': 425,
#   'G/E': 135,
#   'G/F': 134,
#   'G/F#': 101,
#   'G/G#': 585,
#   'G6': 109,
#   'G7': 78,
#   'G7+5': 294,
#   'G7-5': 566,
#   'G7-9': 350,
#   'G7/B': 418,
#   'G7/C': 469,
#   'G7sus4': 235,
#   'G9': 468,
#   'GM7': 297,
#   'Gadd9': 144,
#   'Gadd9/C': 651,
#   'Gadd9/E': 696,
#   'Gaug': 63,
#   'Gaug/C#': 627,
#   'Gdim': 279,
#   'Gdim/D': 330,
#   'Gm': 46,
#   'Gm/A': 233,
#   'Gm/A#': 620,
#   'Gm/B': 680,
#   'Gm/C': 314,
#   'Gm/D#': 526,
#   'Gm/E': 622,
#   'Gm/F': 245,
#   'Gm/F#': 175,
#   'Gm6': 165,
#   'Gm6/A': 451,
#   'Gm7': 37,
#   'Gm7-5': 263,
#   'Gm7-5/C': 416,
#   'Gm7/C': 181,
#   'Gm7/D#': 564,
#   'Gm7/F': 660,
#   'Gm7/F#': 402,
#   'Gm9': 390,
#   'GmM7': 203,
#   'Gmadd9': 394,
#   'Gmaj7': 107,
#   'Gmaj7/A': 210,
#   'Gmaj7/C': 428,
#   'Gmaj9': 447,
#   'Gsus4': 110,
#   'Gsus4/A': 574,
#   'Gsus4/B': 700,
#   'Gsus4/E': 613,
#   'Gsus4/F': 502})

# %%
from sklearn.preprocessing import LabelBinarizer

def capo_binarize(capo):
    binarizer=LabelBinarizer()
    binarized=binarizer.fit_transform(capo)
    return binarized, binarizer.classes_

capo_binarize(["-1","-3","-1","1","0"])
